# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('/Users/hafsatariq/Downloads/Dog_Breeds.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#Fix Image

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
#For grayscale

img_gray = cv2.imread('/Users/hafsatariq/Downloads/Dog_Breeds.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (768, 1024)

# %%
plt.imshow(img_gray, cmap ='gray')

# %%
#Resize

fix_img.shape
# Out:
# (768, 1024, 3)

# %%
new_img = cv2.resize(fix_img, (600, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img, (0, 0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (384, 512, 3)

# %%
#Flip

new_img = cv2.flip(fix_img, 0)

# %%
plt.imshow(new_img)

# %%
#Save

type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %%
#Display Image

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
